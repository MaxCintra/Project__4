# %% [markdown]
# # Data Setup

# %%
import pandas as pd

# Read in all csvs
file1url = 'https://raw.githubusercontent.com/MaxCintra/Project__4/main/Data/2012c.csv'
file1 = pd.read_csv(file1url)
file2url = 'https://raw.githubusercontent.com/MaxCintra/Project__4/main/Data/2013c.csv'
file2= pd.read_csv(file2url)
file3url = 'https://raw.githubusercontent.com/MaxCintra/Project__4/main/Data/2014c.csv'
file3 = pd.read_csv(file3url)
file4url = 'https://raw.githubusercontent.com/MaxCintra/Project__4/main/Data/2015c.csv'
file4 = pd.read_csv(file4url)
file5url = 'https://raw.githubusercontent.com/MaxCintra/Project__4/main/Data/2016c.csv'
file5 = pd.read_csv(file5url)
file6url = 'https://raw.githubusercontent.com/MaxCintra/Project__4/main/Data/2017c.csv'
file6 = pd.read_csv(file6url)
file7url = 'https://raw.githubusercontent.com/MaxCintra/Project__4/main/Data/2018c.csv'
file7 = pd.read_csv(file7url)
file8url = 'https://raw.githubusercontent.com/MaxCintra/Project__4/main/Data/2019c.csv'
file8 = pd.read_csv(file8url)
file9url = 'https://raw.githubusercontent.com/MaxCintra/Project__4/main/Data/2020c.csv'
file9 = pd.read_csv(file9url)
file10url = 'https://raw.githubusercontent.com/MaxCintra/Project__4/main/Data/2021c.csv'
file10 = pd.read_csv(file10url)
file11url = 'https://raw.githubusercontent.com/MaxCintra/Project__4/main/Data/2022c.csv'
file11 = pd.read_csv(file11url)
file12url = 'https://raw.githubusercontent.com/MaxCintra/Project__4/main/Data/2012x.csv'
file12 = pd.read_csv(file12url)
file13url = 'https://raw.githubusercontent.com/MaxCintra/Project__4/main/Data/2013x.csv'
file13 = pd.read_csv(file13url)
file14url = 'https://raw.githubusercontent.com/MaxCintra/Project__4/main/Data/2014x.csv'
file14 = pd.read_csv(file14url)
file15url = 'https://raw.githubusercontent.com/MaxCintra/Project__4/main/Data/2015x.csv'
file15 = pd.read_csv(file15url)
file16url = 'https://raw.githubusercontent.com/MaxCintra/Project__4/main/Data/2016x.csv'
file16 = pd.read_csv(file16url)
file17url = 'https://raw.githubusercontent.com/MaxCintra/Project__4/main/Data/2017x.csv'
file17 = pd.read_csv(file17url)
file18url = 'https://raw.githubusercontent.com/MaxCintra/Project__4/main/Data/2018x.csv'
file18 = pd.read_csv(file18url)
file19url = 'https://raw.githubusercontent.com/MaxCintra/Project__4/main/Data/2019x.csv'
file19 = pd.read_csv(file19url)
file20url = 'https://raw.githubusercontent.com/MaxCintra/Project__4/main/Data/2020x.csv'
file20 = pd.read_csv(file20url)
file21url = 'https://raw.githubusercontent.com/MaxCintra/Project__4/main/Data/2021x.csv'
file21 = pd.read_csv(file21url)
file22url = 'https://raw.githubusercontent.com/MaxCintra/Project__4/main/Data/2022x.csv'
file22 = pd.read_csv(file22url)
file23url = 'https://raw.githubusercontent.com/MaxCintra/Project__4/main/Data/2012t.csv'
file23 = pd.read_csv(file23url)
file24url = 'https://raw.githubusercontent.com/MaxCintra/Project__4/main/Data/2013t.csv'
file24 = pd.read_csv(file24url)
file25url = 'https://raw.githubusercontent.com/MaxCintra/Project__4/main/Data/2014t.csv'
file25 = pd.read_csv(file25url)
file26url = 'https://raw.githubusercontent.com/MaxCintra/Project__4/main/Data/2015t.csv'
file26 = pd.read_csv(file26url)
file27url = 'https://raw.githubusercontent.com/MaxCintra/Project__4/main/Data/2016t.csv'
file27 = pd.read_csv(file27url)
file28url = 'https://raw.githubusercontent.com/MaxCintra/Project__4/main/Data/2017t.csv'
file28 = pd.read_csv(file28url)
file29url = 'https://raw.githubusercontent.com/MaxCintra/Project__4/main/Data/2018t.csv'
file29 = pd.read_csv(file29url)
file30url = 'https://raw.githubusercontent.com/MaxCintra/Project__4/main/Data/2019t.csv'
file30 = pd.read_csv(file30url)
file31url = 'https://raw.githubusercontent.com/MaxCintra/Project__4/main/Data/2020t.csv'
file31 = pd.read_csv(file31url)
file32url = 'https://raw.githubusercontent.com/MaxCintra/Project__4/main/Data/2021t.csv'
file32 = pd.read_csv(file32url)
file33url = 'https://raw.githubusercontent.com/MaxCintra/Project__4/main/Data/2022t.csv'
file33 = pd.read_csv(file33url)



# Merge two DataFrames for each year and merge based on the "Player" column
merged_data_2012 = pd.merge(file1, file12, on='Player', how='inner')
merged_data_2013 = pd.merge(file2, file13, on='Player', how='inner')
merged_data_2014 = pd.merge(file3, file14, on='Player', how='inner')
merged_data_2015 = pd.merge(file4, file15, on='Player', how='inner')
merged_data_2016 = pd.merge(file5, file16, on='Player', how='inner')
merged_data_2017 = pd.merge(file6, file17, on='Player', how='inner')
merged_data_2018 = pd.merge(file7, file18, on='Player', how='inner')
merged_data_2019 = pd.merge(file8, file19, on='Player', how='inner')
merged_data_2020 = pd.merge(file9, file20, on='Player', how='inner')
merged_data_2021 = pd.merge(file10, file21, on='Player', how='inner')
merged_data_2022 = pd.merge(file11, file22, on='Player', how='inner')

# %%
fmerged_data_2012 = pd.merge(merged_data_2012, file23, on='Player', how='inner')
fmerged_data_2013 = pd.merge(merged_data_2013, file24, on='Player', how='inner')
fmerged_data_2014 = pd.merge(merged_data_2014, file25, on='Player', how='inner')
fmerged_data_2015 = pd.merge(merged_data_2015, file26, on='Player', how='inner')
fmerged_data_2016 = pd.merge(merged_data_2016, file27, on='Player', how='inner')
fmerged_data_2017 = pd.merge(merged_data_2017, file28, on='Player', how='inner')
fmerged_data_2018 = pd.merge(merged_data_2018, file29, on='Player', how='inner')
fmerged_data_2019 = pd.merge(merged_data_2019, file30, on='Player', how='inner')
fmerged_data_2020 = pd.merge(merged_data_2020, file31, on='Player', how='inner')
fmerged_data_2021 = pd.merge(merged_data_2021, file32, on='Player', how='inner')
fmerged_data_2022 = pd.merge(merged_data_2022, file33, on='Player', how='inner')

# %%
master_combined_data = pd.concat([fmerged_data_2012,
fmerged_data_2013,
fmerged_data_2014,
fmerged_data_2015,
fmerged_data_2016,
fmerged_data_2017,
fmerged_data_2018,
fmerged_data_2019,
fmerged_data_2020,
fmerged_data_2021,
fmerged_data_2022])

master_combined_data
# Out:
#      Rnd  Pick            Player Pos  AP1  PB        College/Univ     -9999  \
# 0      1     1       Andrew Luck  QB    0   4            Stanford  LuckAn00
# 1      1     3  Trent Richardson  RB    0   0             Alabama  RichTr00
# 2      1     4        Matt Kalil   T    0   1                 USC  KaliMa00
# 3      1     5   Justin Blackmon  WR    0   0        Oklahoma St.  BlacJu00
# 4      1     6  Morris Claiborne  DB    0   0                 LSU  ClaiMo00
# ..   ...   ...               ...  ..  ...  ..                 ...       ...
# 204    7   251     Isiah Pacheco  RB    0   0             Rutgers  PachIs00
# 205    7   255      Trenton Gill   P    0   0  North Carolina St.  GillTr01
# 206    7   256      Jesse Luketa  LB    0   0            Penn St.  LukeJe00
# 207    7   257     Marquis Hayes  OL    0   0            Oklahoma  HayeMa00
# 208    7   262       Brock Purdy  QB    0   0            Iowa St.  PurdBr00
#
# ...

# %%
# Save the master combined DataFrame as a CSV file
master_combined_data.to_csv('Data/eleven_year_data.csv', index=False)

# %% [markdown]
# # Data Cleaning

# %%
df = pd.read_csv('Data/eleven_year_data.csv')
df.head()
# Out:
#    Rnd  Pick            Player Pos  AP1  PB  College/Univ     -9999    Ht  \
# 0    1     1       Andrew Luck  QB    0   4      Stanford  LuckAn00   6-4
# 1    1     3  Trent Richardson  RB    0   0       Alabama  RichTr00   5-9
# 2    1     4        Matt Kalil   T    0   1           USC  KaliMa00   6-7
# 3    1     5   Justin Blackmon  WR    0   0  Oklahoma St.  BlacJu00   6-1
# 4    1     6  Morris Claiborne  DB    0   0           LSU  ClaiMo00  5-11
#
#       Wt  40yd  Vertical  Bench  Broad Jump  3Cone  Shuttle  \
# 0  234.0  4.59      36.0    NaN       124.0   6.80     4.28
# 1  228.0  4.48       NaN    NaN         NaN    NaN      NaN
# 2  306.0  4.96      27.0   30.0         NaN   7.33     4.65
# 3  207.0  4.46       NaN   14.0         NaN    NaN      NaN
# 4  188.0  4.50      34.5    NaN       118.0   7.01     4.12
#
#   Player-additional_x                           Drafted (tm/rnd/yr)  \
# 0            LuckAn00    Indianapolis Colts / 1st / 1st pick / 2012
# ...

# %%
df['AP1'] = df['AP1'].apply(lambda x: 1 if x > 0 else 0)
df['PB'] = df['PB'].apply(lambda x: 1 if x > 0 else 0)

# %%
df.head()
# Out:
#    Rnd  Pick            Player Pos  AP1  PB  College/Univ     -9999    Ht  \
# 0    1     1       Andrew Luck  QB    0   1      Stanford  LuckAn00   6-4
# 1    1     3  Trent Richardson  RB    0   0       Alabama  RichTr00   5-9
# 2    1     4        Matt Kalil   T    0   1           USC  KaliMa00   6-7
# 3    1     5   Justin Blackmon  WR    0   0  Oklahoma St.  BlacJu00   6-1
# 4    1     6  Morris Claiborne  DB    0   0           LSU  ClaiMo00  5-11
#
#       Wt  40yd  Vertical  Bench  Broad Jump  3Cone  Shuttle  \
# 0  234.0  4.59      36.0    NaN       124.0   6.80     4.28
# 1  228.0  4.48       NaN    NaN         NaN    NaN      NaN
# 2  306.0  4.96      27.0   30.0         NaN   7.33     4.65
# 3  207.0  4.46       NaN   14.0         NaN    NaN      NaN
# 4  188.0  4.50      34.5    NaN       118.0   7.01     4.12
#
#   Player-additional_x                           Drafted (tm/rnd/yr)  \
# 0            LuckAn00    Indianapolis Colts / 1st / 1st pick / 2012
# ...

# %%
df[['Feet', 'Inches']] = df['Ht'].str.split('-', expand=True)

# %%
df['Feet'] = pd.to_numeric(df['Feet'])
df['Inches'] = pd.to_numeric(df['Inches'])
df['Ht'] = df['Feet'] * 12 + df['Inches']

# %%
df.head()
# Out:
#    Rnd  Pick            Player Pos  AP1  PB  College/Univ     -9999    Ht  \
# 0    1     1       Andrew Luck  QB    0   1      Stanford  LuckAn00  76.0
# 1    1     3  Trent Richardson  RB    0   0       Alabama  RichTr00  69.0
# 2    1     4        Matt Kalil   T    0   1           USC  KaliMa00  79.0
# 3    1     5   Justin Blackmon  WR    0   0  Oklahoma St.  BlacJu00  73.0
# 4    1     6  Morris Claiborne  DB    0   0           LSU  ClaiMo00  71.0
#
#       Wt  ...  Vertical  Bench  Broad Jump  3Cone  Shuttle  \
# 0  234.0  ...      36.0    NaN       124.0   6.80     4.28
# 1  228.0  ...       NaN    NaN         NaN    NaN      NaN
# 2  306.0  ...      27.0   30.0         NaN   7.33     4.65
# 3  207.0  ...       NaN   14.0         NaN    NaN      NaN
# 4  188.0  ...      34.5    NaN       118.0   7.01     4.12
#
#    Player-additional_x                           Drafted (tm/rnd/yr)  \
# 0             LuckAn00    Indianapolis Colts / 1st / 1st pick / 2012
# ...

# %%
df['Drafted_Binary'] = df['Drafted (tm/rnd/yr)'].notna().astype(int)

# %%
df
# Out:
#       Rnd  Pick            Player Pos  AP1  PB        College/Univ     -9999  \
# 0       1     1       Andrew Luck  QB    0   1            Stanford  LuckAn00
# 1       1     3  Trent Richardson  RB    0   0             Alabama  RichTr00
# 2       1     4        Matt Kalil   T    0   1                 USC  KaliMa00
# 3       1     5   Justin Blackmon  WR    0   0        Oklahoma St.  BlacJu00
# 4       1     6  Morris Claiborne  DB    0   0                 LSU  ClaiMo00
# ...   ...   ...               ...  ..  ...  ..                 ...       ...
# 2304    7   251     Isiah Pacheco  RB    0   0             Rutgers  PachIs00
# 2305    7   255      Trenton Gill   P    0   0  North Carolina St.  GillTr01
# 2306    7   256      Jesse Luketa  LB    0   0            Penn St.  LukeJe00
# 2307    7   257     Marquis Hayes  OL    0   0            Oklahoma  HayeMa00
# 2308    7   262       Brock Purdy  QB    0   0            Iowa St.  PurdBr00
#
# ...

# %%
columns_to_drop = ['-9999', 'Player-additional_x', 'Player-additional_y', 'Feet', 'Inches', 'Drafted (tm/rnd/yr)']
df = df.drop(columns=columns_to_drop)

# %%
df.head()
# Out:
#    Rnd  Pick            Player Pos  AP1  PB  College/Univ    Ht     Wt  40yd  \
# 0    1     1       Andrew Luck  QB    0   1      Stanford  76.0  234.0  4.59
# 1    1     3  Trent Richardson  RB    0   0       Alabama  69.0  228.0  4.48
# 2    1     4        Matt Kalil   T    0   1           USC  79.0  306.0  4.96
# 3    1     5   Justin Blackmon  WR    0   0  Oklahoma St.  73.0  207.0  4.46
# 4    1     6  Morris Claiborne  DB    0   0           LSU  71.0  188.0  4.50
#
#    Vertical  Bench  Broad Jump  3Cone  Shuttle  Drafted_Binary
# 0      36.0    NaN       124.0   6.80     4.28               1
# 1       NaN    NaN         NaN    NaN      NaN               1
# 2      27.0   30.0         NaN   7.33     4.65               1
# 3       NaN   14.0         NaN    NaN      NaN               1
# 4      34.5    NaN       118.0   7.01     4.12               1

# %% [markdown]
# # Imputation

# %%
positions = df['Pos'].unique()

# Iterate over each position group
for pos in positions:
    # Filter the data for the current position
    pos_data = df[df['Pos'] == pos].copy()

    # Calculate the mean for selected columns
    mean_values = pos_data[['40yd', 'Vertical', 'Bench', 'Broad Jump', '3Cone', 'Shuttle']].mean()

    # Impute missing values with mean values in the copy
    pos_data[['40yd', 'Vertical', 'Bench', 'Broad Jump', '3Cone', 'Shuttle']] = pos_data[['40yd', 'Vertical', 'Bench', 'Broad Jump', '3Cone', 'Shuttle']].fillna(mean_values)

    # Merge imputed data back into the original dataset
    df.update(pos_data)

df
# Out:
#       Rnd   Pick            Player Pos  AP1   PB        College/Univ    Ht  \
# 0     1.0    1.0       Andrew Luck  QB  0.0  1.0            Stanford  76.0
# 1     1.0    3.0  Trent Richardson  RB  0.0  0.0             Alabama  69.0
# 2     1.0    4.0        Matt Kalil   T  0.0  1.0                 USC  79.0
# 3     1.0    5.0   Justin Blackmon  WR  0.0  0.0        Oklahoma St.  73.0
# 4     1.0    6.0  Morris Claiborne  DB  0.0  0.0                 LSU  71.0
# ...   ...    ...               ...  ..  ...  ...                 ...   ...
# 2304  7.0  251.0     Isiah Pacheco  RB  0.0  0.0             Rutgers  70.0
# 2305  7.0  255.0      Trenton Gill   P  0.0  0.0  North Carolina St.  76.0
# 2306  7.0  256.0      Jesse Luketa  LB  0.0  0.0            Penn St.  75.0
# 2307  7.0  257.0     Marquis Hayes  OL  0.0  0.0            Oklahoma  77.0
# 2308  7.0  262.0       Brock Purdy  QB  0.0  0.0            Iowa St.  73.0
#
# ...

# %%
df = df[df['Pos'] != 'K']

# %%
df
# Out:
#       Rnd   Pick            Player Pos  AP1   PB        College/Univ    Ht  \
# 0     1.0    1.0       Andrew Luck  QB  0.0  1.0            Stanford  76.0
# 1     1.0    3.0  Trent Richardson  RB  0.0  0.0             Alabama  69.0
# 2     1.0    4.0        Matt Kalil   T  0.0  1.0                 USC  79.0
# 3     1.0    5.0   Justin Blackmon  WR  0.0  0.0        Oklahoma St.  73.0
# 4     1.0    6.0  Morris Claiborne  DB  0.0  0.0                 LSU  71.0
# ...   ...    ...               ...  ..  ...  ...                 ...   ...
# 2304  7.0  251.0     Isiah Pacheco  RB  0.0  0.0             Rutgers  70.0
# 2305  7.0  255.0      Trenton Gill   P  0.0  0.0  North Carolina St.  76.0
# 2306  7.0  256.0      Jesse Luketa  LB  0.0  0.0            Penn St.  75.0
# 2307  7.0  257.0     Marquis Hayes  OL  0.0  0.0            Oklahoma  77.0
# 2308  7.0  262.0       Brock Purdy  QB  0.0  0.0            Iowa St.  73.0
#
# ...

# %%
# Replace NaN values in 'Bench' with -9999 for positions that don't compete
df['Bench'].fillna(15, inplace=True)
# Out:
# C:\Users\bosto\AppData\Local\Temp\ipykernel_16692\1261737949.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Bench'].fillna(15, inplace=True)

# %%
df
# Out:
#       Rnd   Pick            Player Pos  AP1   PB        College/Univ    Ht  \
# 0     1.0    1.0       Andrew Luck  QB  0.0  1.0            Stanford  76.0
# 1     1.0    3.0  Trent Richardson  RB  0.0  0.0             Alabama  69.0
# 2     1.0    4.0        Matt Kalil   T  0.0  1.0                 USC  79.0
# 3     1.0    5.0   Justin Blackmon  WR  0.0  0.0        Oklahoma St.  73.0
# 4     1.0    6.0  Morris Claiborne  DB  0.0  0.0                 LSU  71.0
# ...   ...    ...               ...  ..  ...  ...                 ...   ...
# 2304  7.0  251.0     Isiah Pacheco  RB  0.0  0.0             Rutgers  70.0
# 2305  7.0  255.0      Trenton Gill   P  0.0  0.0  North Carolina St.  76.0
# 2306  7.0  256.0      Jesse Luketa  LB  0.0  0.0            Penn St.  75.0
# 2307  7.0  257.0     Marquis Hayes  OL  0.0  0.0            Oklahoma  77.0
# 2308  7.0  262.0       Brock Purdy  QB  0.0  0.0            Iowa St.  73.0
#
# ...

# %%
has_nan = df.isna().any().any()

if has_nan:
    print("There are NaN values in the DataFrame.")
else:
    print("There are no NaN values in the DataFrame.")
# Out:
# There are NaN values in the DataFrame.

# %%
nan_locations = df[df.isna().any(axis=1)]

# Print rows and columns with NaN values
print("Rows with NaN values:")
print(nan_locations)

print("\nColumns with NaN values:")
print(df.columns[df.isna().any()].tolist())
# Out:
# Rows with NaN values:
#       Rnd   Pick             Player Pos  AP1   PB    College/Univ  Ht     Wt  \
# 1911  2.0   34.0       Elijah Moore  WR  0.0  0.0     Mississippi NaN    NaN
# 1939  3.0   65.0        Andre Cisco  DB  0.0  0.0        Syracuse NaN    NaN
# 1942  3.0   70.0  Brady Christensen  OL  0.0  0.0             BYU NaN    NaN
# 1982  4.0  116.0      Elerson Smith  DL  0.0  0.0   Northern Iowa NaN    NaN
# 2003  4.0  143.0    Tyree Gillespie   S  0.0  0.0        Missouri NaN    NaN
# 2009  5.0  150.0   Kenneth Gainwell  RB  0.0  0.0         Memphis NaN  201.0
# 2027  5.0  170.0      Garret Wallow  LB  0.0  0.0             TCU NaN    NaN
# 2035  5.0  180.0    Talanoa Hufanga   S  1.0  1.0             USC NaN    NaN
# 2043  6.0  188.0    Joshuah Bledsoe   S  0.0  0.0        Missouri NaN    NaN
# 2052  6.0  198.0     Larry Rountree  RB  0.0  0.0        Missouri NaN    NaN
# 2069  6.0  216.0       Quincy Roche  DL  0.0  0.0      Miami (FL) NaN    NaN
# ...

# %%
df.dropna(inplace=True)
# Out:
# C:\Users\bosto\AppData\Local\Temp\ipykernel_16692\1379821321.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
has_nan = df.isna().any().any()

if has_nan:
    print("There are NaN values in the DataFrame.")
else:
    print("There are no NaN values in the DataFrame.")
# Out:
# There are no NaN values in the DataFrame.

# %%
unique_positions = df['Pos'].unique()
print(unique_positions)
# Out:
# ['QB' 'RB' 'T' 'WR' 'DB' 'LB' 'DT' 'DE' 'G' 'TE' 'C' 'P' 'OL' 'NT' 'FB'
#  'OLB' 'CB' 'S' 'ILB' 'LS' 'DL']

# %%
position_encoding = {
    'QB': 1,
    'RB': 2,
    'T': 3,
    'WR': 4,
    'DB': 5,
    'LB': 6,
    'DT': 7,
    'DE': 8,
    'G': 9,
    'TE': 10,
    'C': 11,
    'P': 12,
    'OL': 13,
    'NT': 14,
    'FB': 15,
    'OLB': 16,
    'CB': 17,
    'S': 18,
    'ILB': 19,
    'LS': 20,
    'DL': 21,
}
df['Pos_encoded'] = df['Pos'].map(position_encoding)
# Out:
# C:\Users\bosto\AppData\Local\Temp\ipykernel_16692\1412481398.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pos_encoded'] = df['Pos'].map(position_encoding)

# %%
df
# Out:
#       Rnd   Pick            Player Pos  AP1   PB        College/Univ    Ht  \
# 0     1.0    1.0       Andrew Luck  QB  0.0  1.0            Stanford  76.0
# 1     1.0    3.0  Trent Richardson  RB  0.0  0.0             Alabama  69.0
# 2     1.0    4.0        Matt Kalil   T  0.0  1.0                 USC  79.0
# 3     1.0    5.0   Justin Blackmon  WR  0.0  0.0        Oklahoma St.  73.0
# 4     1.0    6.0  Morris Claiborne  DB  0.0  0.0                 LSU  71.0
# ...   ...    ...               ...  ..  ...  ...                 ...   ...
# 2304  7.0  251.0     Isiah Pacheco  RB  0.0  0.0             Rutgers  70.0
# 2305  7.0  255.0      Trenton Gill   P  0.0  0.0  North Carolina St.  76.0
# 2306  7.0  256.0      Jesse Luketa  LB  0.0  0.0            Penn St.  75.0
# 2307  7.0  257.0     Marquis Hayes  OL  0.0  0.0            Oklahoma  77.0
# 2308  7.0  262.0       Brock Purdy  QB  0.0  0.0            Iowa St.  73.0
#
# ...

# %%
unique_schools = df['College/Univ'].unique()
print(unique_schools)
# Out:
# ['Stanford' 'Alabama' 'USC' 'Oklahoma St.' 'LSU' 'Texas A&M' 'Boston Col.'
#  'South Carolina' 'Memphis' 'Mississippi St.' 'Notre Dame' 'West Virginia'
#  'North Carolina' 'Boise St.' 'Baylor' 'Syracuse' 'Iowa' 'Illinois'
#  'Wisconsin' 'Virginia Tech' 'Appalachian St.' 'Cincinnati' 'California'
#  'Clemson' 'Midwestern St.' 'Georgia' 'Georgia Tech' 'Connecticut'
#  'Michigan St.' 'Penn St.' 'Oklahoma' 'Ohio St.' 'Arizona St.' 'Nebraska'
#  'Marshall' 'Iowa St.' 'Oregon' 'Vanderbilt' 'Montana' 'Central Florida'
#  'San Diego St.' 'North Carolina St.' 'SMU' 'Miami (FL)' 'Arkansas St.'
#  'Missouri' 'Michigan' 'Rutgers' 'Temple' 'Louisiana' 'Arizona' 'Arkansas'
#  'Southern Miss' 'Florida International' 'Utah' 'Wake Forest'
#  'Florida St.' 'Utah St.' 'Fresno St.' 'Washington' 'Mississippi'
#  'Florida' 'Texas' 'Nevada' 'South Carolina St.' 'Auburn' 'Maine'
#  'Tennessee' 'Coastal Carolina' 'TCU' 'Colorado' 'Samford' 'Troy'
# ...

# %%
school_encoding = {}
for i, school in enumerate(unique_schools):
    school_encoding[school] = i

# %%
df['College/Univ_encoded'] = df['College/Univ'].map(school_encoding)
# Out:
# C:\Users\bosto\AppData\Local\Temp\ipykernel_16692\3514403639.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['College/Univ_encoded'] = df['College/Univ'].map(school_encoding)

# %%
df
# Out:
#       Rnd   Pick            Player Pos  AP1   PB        College/Univ    Ht  \
# 0     1.0    1.0       Andrew Luck  QB  0.0  1.0            Stanford  76.0
# 1     1.0    3.0  Trent Richardson  RB  0.0  0.0             Alabama  69.0
# 2     1.0    4.0        Matt Kalil   T  0.0  1.0                 USC  79.0
# 3     1.0    5.0   Justin Blackmon  WR  0.0  0.0        Oklahoma St.  73.0
# 4     1.0    6.0  Morris Claiborne  DB  0.0  0.0                 LSU  71.0
# ...   ...    ...               ...  ..  ...  ...                 ...   ...
# 2304  7.0  251.0     Isiah Pacheco  RB  0.0  0.0             Rutgers  70.0
# 2305  7.0  255.0      Trenton Gill   P  0.0  0.0  North Carolina St.  76.0
# 2306  7.0  256.0      Jesse Luketa  LB  0.0  0.0            Penn St.  75.0
# 2307  7.0  257.0     Marquis Hayes  OL  0.0  0.0            Oklahoma  77.0
# 2308  7.0  262.0       Brock Purdy  QB  0.0  0.0            Iowa St.  73.0
#
# ...

# %%
#df.to_csv('final_data.csv', index=False)

# %%
alabama_players = df[df['College/Univ'] == 'USC']
print(alabama_players)
# Out:
#       Rnd   Pick               Player  Pos  AP1   PB College/Univ    Ht  \
# 2     1.0    4.0           Matt Kalil    T  0.0  1.0          USC  79.0
# 26    1.0   28.0           Nick Perry   DE  0.0  0.0          USC  75.0
# 118   4.0  128.0        Rhett Ellison   RB  0.0  0.0          USC  77.0
# 249   2.0   41.0         Robert Woods   WR  0.0  0.0          USC  72.0
# 278   3.0   71.0        T.J. McDonald   DB  0.0  0.0          USC  74.0
# 304   4.0   98.0         Matt Barkley   QB  0.0  0.0          USC  74.0
# 327   4.0  121.0        Khaled Holmes    C  0.0  0.0          USC  75.0
# 467   2.0   39.0          Marqise Lee   WR  0.0  0.0          USC  72.0
# 498   3.0   70.0        Marcus Martin    C  0.0  0.0          USC  75.0
# 594   5.0  174.0        Devon Kennard   DE  0.0  0.0          USC  75.0
# 651   1.0    6.0     Leonard Williams   DE  0.0  1.0          USC  77.0
# 668   1.0   20.0       Nelson Agholor   WR  0.0  0.0          USC  72.0
# ...

# %%
import json
import psycopg2
import pandas as pd
from sqlalchemy import create_engine

# PLEASE OPEN JSON FILE create_database_creds.json AND ENTER YOUR CREDENTIALS
with open('create_database_creds.json') as O:
    config = json.load(O)
username = config['user']
password = config['password']
db_host = config['host']
db_port = config['port']
db_name = 'nfl_prediction_data_db'

# Create a connection to PostgreSQL
conn = psycopg2.connect(
    host=db_host,
    port=db_port,
    user=username,
    password=password,
)

conn.autocommit = True
cursor = conn.cursor()

# Create the database if it doesn't exist
cursor.execute(f"CREATE DATABASE {db_name}")


connection_path = f"postgresql://{username}:{password}@{db_host}:{db_port}/{db_name}"
engine = create_engine(connection_path)

table_name = 'nfl_final_data'

# Import data into the database using the engine
df.to_sql(table_name, engine, if_exists='replace', index=False)


engine.dispose()
